# %%
pip install -r requirements.txt
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import subprocess
subprocess.run(["python", "job_hunter.py"])
# Out:
# CompletedProcess(args=['python', 'job_hunter.py'], returncode=0)

# %%
import os
os.environ["PYTHONIOENCODING"] = "utf-8"
# !set PYTHONIOENCODING=utf-8 && python job_hunter.py
# Out:
# ...
#   ðŸŽ¯ JOB HUNTER â€“ Iniciando busca de vagas
#   ðŸ“… 09/04/2026 09:45
# ...
#
# ðŸ“‚ Cache carregado: 57 vagas jÃ¡ vistas
#
# ðŸŒ� Iniciando coleta nas plataformas...
#
# ðŸ”� Buscando: 'desenvolvedor python'
#   â†’ Indeed...
#   [Indeed] Erro ao buscar 'desenvolvedor python': 403 Client Error: Forbidden for url: https://br.indeed.com/jobs?q=desenvolvedor+python&l=Brasil&fromage=1&sort=date
#   â†’ Gupy...
#   [Gupy] Erro ao buscar 'desenvolvedor python': 400 Client Error: Bad Request for url: https://portal.api.gupy.io/api/job?jobName=desenvolvedor+python&limit=20&offset=0
#   â†’ LinkedIn...
#
# ðŸ”� Buscando: 'engenheiro de software'
#   â†’ Indeed...
#   [Indeed] Erro ao buscar 'engenheiro de software': 403 Client Error: Forbidden for url: https://br.indeed.com/jobs?q=engenheiro+de+software&l=Brasil&fromage=1&sort=date
#   â†’ Gupy...
# ...

# %%
# !python job_hunter.py
# Out:
# ...
#   ðŸŽ¯ JOB HUNTER â€“ Iniciando busca de vagas
#   ðŸ“… 09/04/2026 09:52
# ...
#
# ðŸ“‚ Cache carregado: 119 vagas jÃ¡ vistas
#
# ðŸŒ� Iniciando coleta nas plataformas...
#
# ðŸ”� Buscando: 'gerente comercial'
#   â†’ Indeed...
#   [Indeed] Erro ao buscar 'gerente comercial': 403 Client Error: Forbidden for url: https://br.indeed.com/jobs?q=gerente+comercial&l=Brasil&fromage=1&sort=date
#   â†’ Gupy...
#   [Gupy] Erro ao buscar 'gerente comercial': 400 Client Error: Bad Request for url: https://portal.api.gupy.io/api/job?jobName=gerente+comercial&limit=20&offset=0
#   â†’ LinkedIn...
#
# ðŸ”� Buscando: 'gerente geral'
#   â†’ Indeed...
#   [Indeed] Erro ao buscar 'gerente geral': 403 Client Error: Forbidden for url: https://br.indeed.com/jobs?q=gerente+geral&l=Brasil&fromage=1&sort=date
#   â†’ Gupy...
#   [Gupy] Erro ao buscar 'gerente geral': 400 Client Error: Bad Request for url: https://portal.api.gupy.io/api/job?jobName=gerente+geral&limit=20&offset=0
#   â†’ LinkedIn...
#
# ...

# %%
import smtplib
import os
from dotenv import load_dotenv

load_dotenv()

email = os.getenv("EMAIL_REMETENTE")
senha = os.getenv("EMAIL_SENHA")

print(f"Email: {email}")
print(f"Senha carregada: {'OK' if senha else 'VAZIA'}")
print(f"Tamanho da senha: {len(senha) if senha else 0} caracteres")

try:
    with smtplib.SMTP_SSL("smtp.gmail.com", 465) as smtp:
        smtp.login(email, senha)
        print("✅ Login realizado com sucesso!")
except Exception as e:
    print(f"❌ Erro: {e}")
# Out:
# Email: None
# Senha carregada: VAZIA
# Tamanho da senha: 0 caracteres
# ❌ Erro: (334, b'UGFzc3dvcmQ6')

# %%
import os
from dotenv import load_dotenv

# Caminho explícito para o .env
dotenv_path = r"C:\Users\Minoru\OneDrive\Documentos\Minoru\Projetos_Python\job_hunter\.env"

load_dotenv(dotenv_path=dotenv_path)

email = os.getenv("EMAIL_REMETENTE")
senha = os.getenv("EMAIL_SENHA")

print(f"Email: {email}")
print(f"Senha carregada: {'OK' if senha else 'VAZIA'}")
print(f"Tamanho da senha: {len(senha) if senha else 0} caracteres")
# Out:
# Email: None
# Senha carregada: VAZIA
# Tamanho da senha: 0 caracteres

# %%
with open(r"C:\Users\Minoru\OneDrive\Documentos\Minoru\Projetos_Python\job_hunter\.env", "r") as f:
    print(repr(f.read()))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 with open(r"C:\Users\Minoru\OneDrive\Documentos\Minoru\Projetos_Python\job_hunter\.env", "r") as f:
#       2     print(repr(f.read()))
#
# File ~\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py:324, in _modified_open(file, *args, **kwargs)
#     317 if file in {0, 1, 2}:
#     318     raise ValueError(
#     319         f"IPython won't let you open fd={file} by default "
#     320         "as it is likely to crash IPython. If you know what you are doing, "
#     321         "you can use builtins' open."
#     322     )
# --> 324 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'C:\\Users\\Minoru\\OneDrive\\Documentos\\Minoru\\Projetos_Python\\job_hunter\\.env'

# %%
env_content = """EMAIL_REMETENTE=cmabe01@gmail.com
EMAIL_SENHA=irichfcfolohawfp
EMAIL_DESTINATARIO=cmabe01@gmail.com
"""

with open(r"C:\Users\Minoru\OneDrive\Documentos\Minoru\Projetos_Python\job_hunter\.env", "w") as f:
    f.write(env_content)

print("✅ Arquivo .env criado com sucesso!")
# Out:
# ✅ Arquivo .env criado com sucesso!

# %%
import smtplib
import os
from dotenv import load_dotenv

dotenv_path = r"C:\Users\Minoru\OneDrive\Documentos\Minoru\Projetos_Python\job_hunter\.env"
load_dotenv(dotenv_path=dotenv_path, override=True)

email = os.getenv("EMAIL_REMETENTE")
senha = os.getenv("EMAIL_SENHA")

print(f"Email: {email}")
print(f"Senha carregada: {'OK' if senha else 'VAZIA'}")
print(f"Tamanho da senha: {len(senha) if senha else 0} caracteres")

try:
    with smtplib.SMTP_SSL("smtp.gmail.com", 465) as smtp:
        smtp.login(email, senha)
        print("✅ Login realizado com sucesso!")
except Exception as e:
    print(f"❌ Erro: {e}")
# Out:
# Email: cmabe01@gmail.com
# Senha carregada: OK
# Tamanho da senha: 16 caracteres
# ✅ Login realizado com sucesso!

# %%
# !python "C:\Users\Minoru\OneDrive\Documentos\Minoru\Projetos_Python\job_hunter\job_hunter.py"
# Out:
# ...
#   ðŸŽ¯ JOB HUNTER â€“ Iniciando busca de vagas
#   ðŸ“… 09/04/2026 09:59
# ...
#
# ðŸ“‚ Cache carregado: 119 vagas jÃ¡ vistas
#
# ðŸŒ� Iniciando coleta nas plataformas...
#
# ðŸ”� Buscando: 'gerente comercial'
#   â†’ Indeed...
#   [Indeed] Erro ao buscar 'gerente comercial': 403 Client Error: Forbidden for url: https://br.indeed.com/jobs?q=gerente+comercial&l=Brasil&fromage=1&sort=date
#   â†’ Gupy...
#   [Gupy] Erro ao buscar 'gerente comercial': 400 Client Error: Bad Request for url: https://portal.api.gupy.io/api/job?jobName=gerente+comercial&limit=20&offset=0
#   â†’ LinkedIn...
#
# ðŸ”� Buscando: 'gerente geral'
#   â†’ Indeed...
#   [Indeed] Erro ao buscar 'gerente geral': 403 Client Error: Forbidden for url: https://br.indeed.com/jobs?q=gerente+geral&l=Brasil&fromage=1&sort=date
#   â†’ Gupy...
#   [Gupy] Erro ao buscar 'gerente geral': 400 Client Error: Bad Request for url: https://portal.api.gupy.io/api/job?jobName=gerente+geral&limit=20&offset=0
#   â†’ LinkedIn...
#
# ...

# %%
# Lê o arquivo atual
with open(r"C:\Users\Minoru\OneDrive\Documentos\Minoru\Projetos_Python\job_hunter\job_hunter.py", "r", encoding="utf-8") as f:
    conteudo = f.read()

# Substitui o load_dotenv() simples pelo com caminho explícito
conteudo = conteudo.replace(
    "load_dotenv()",
    r"load_dotenv(dotenv_path=r'C:\Users\Minoru\OneDrive\Documentos\Minoru\Projetos_Python\job_hunter\.env', override=True)"
)

# Salva
with open(r"C:\Users\Minoru\OneDrive\Documentos\Minoru\Projetos_Python\job_hunter\job_hunter.py", "w", encoding="utf-8") as f:
    f.write(conteudo)

print("✅ job_hunter.py atualizado!")
# Out:
# ✅ job_hunter.py atualizado!

# %%
# !python "C:\Users\Minoru\OneDrive\Documentos\Minoru\Projetos_Python\job_hunter\job_hunter.py"
# Out:
# ...
#   ðŸŽ¯ JOB HUNTER â€“ Iniciando busca de vagas
#   ðŸ“… 09/04/2026 10:01
# ...
#
# ðŸ“‚ Cache carregado: 121 vagas jÃ¡ vistas
#
# ðŸŒ� Iniciando coleta nas plataformas...
#
# ðŸ”� Buscando: 'gerente comercial'
#   â†’ Indeed...
#   [Indeed] Erro ao buscar 'gerente comercial': 403 Client Error: Forbidden for url: https://br.indeed.com/jobs?q=gerente+comercial&l=Brasil&fromage=1&sort=date
#   â†’ Gupy...
#   [Gupy] Erro ao buscar 'gerente comercial': 400 Client Error: Bad Request for url: https://portal.api.gupy.io/api/job?jobName=gerente+comercial&limit=20&offset=0
#   â†’ LinkedIn...
#
# ðŸ”� Buscando: 'gerente geral'
#   â†’ Indeed...
#   [Indeed] Erro ao buscar 'gerente geral': 403 Client Error: Forbidden for url: https://br.indeed.com/jobs?q=gerente+geral&l=Brasil&fromage=1&sort=date
#   â†’ Gupy...
#   [Gupy] Erro ao buscar 'gerente geral': 400 Client Error: Bad Request for url: https://portal.api.gupy.io/api/job?jobName=gerente+geral&limit=20&offset=0
#   â†’ LinkedIn...
#
# ...

# %%
with open(r"C:\Users\Minoru\OneDrive\Documentos\Minoru\Projetos_Python\job_hunter\job_hunter.py", "r", encoding="utf-8") as f:
    conteudo = f.read()

# Conta ocorrências
count = conteudo.count("load_dotenv")
print(f"Ocorrências de load_dotenv: {count}")

# Mostra cada linha que contém load_dotenv
for i, linha in enumerate(conteudo.split("\n"), 1):
    if "load_dotenv" in linha:
        print(f"Linha {i}: {linha}")
# Out:
# Ocorrências de load_dotenv: 0

# %%
with open(r"C:\Users\Minoru\OneDrive\Documentos\Minoru\Projetos_Python\job_hunter\job_hunter.py", "r", encoding="utf-8") as f:
    conteudo = f.read()

# Procura por como as credenciais são lidas
for i, linha in enumerate(conteudo.split("\n"), 1):
    if any(x in linha.lower() for x in ["email", "senha", "password", "getenv", "dotenv", ".env", "smtp"]):
        print(f"Linha {i}: {linha}")
# Out:
# Linha 3: Job Hunter - Automated Job Search & Daily Email Report
# Linha 4: Busca vagas no LinkedIn, Indeed e Gupy e envia relatório diário por email (Gmail)
# Linha 10: import smtplib
# Linha 13: from email.mime.multipart import MIMEMultipart
# Linha 14: from email.mime.text import MIMEText
# Linha 30:     # Gmail - configure no arquivo .env ou diretamente aqui
# Linha 31:     "gmail_sender": os.getenv("GMAIL_SENDER", "cmabe0@gmail.com"),
# Linha 32:     "gmail_password": os.getenv("GMAIL_APP_PASSWORD", "irichfcfolohawfp"),
# Linha 33:     "gmail_recipient": os.getenv("GMAIL_RECIPIENT", "cmabe01@gmail.com"),
# Linha 427: # ─── ENVIO DE EMAIL ────────────────────────────────────────────────────────────
# Linha 429: def send_email(html_body: str, total_jobs: int, config: dict):
# Linha 440:     print(f"\n📧 Enviando email para {config['gmail_recipient']}...")
# Linha 441:     with smtplib.SMTP_SSL("smtp.gmail.com", 465) as server:
# ...

# %%
with open(r"C:\Users\Minoru\OneDrive\Documentos\Minoru\Projetos_Python\job_hunter\job_hunter.py", "r", encoding="utf-8") as f:
    conteudo = f.read()

# Corrige o email remetente (faltava o "1")
conteudo = conteudo.replace(
    '"gmail_sender": os.getenv("GMAIL_SENDER", "cmabe0@gmail.com")',
    '"gmail_sender": os.getenv("GMAIL_SENDER", "cmabe01@gmail.com")'
)

with open(r"C:\Users\Minoru\OneDrive\Documentos\Minoru\Projetos_Python\job_hunter\job_hunter.py", "w", encoding="utf-8") as f:
    f.write(conteudo)

print("✅ Corrigido!")
# Out:
# ✅ Corrigido!

# %%
# !python "C:\Users\Minoru\OneDrive\Documentos\Minoru\Projetos_Python\job_hunter\job_hunter.py"
# Out:
# ...
#   ðŸŽ¯ JOB HUNTER â€“ Iniciando busca de vagas
#   ðŸ“… 09/04/2026 10:04
# ...
#
# ðŸ“‚ Cache carregado: 121 vagas jÃ¡ vistas
#
# ðŸŒ� Iniciando coleta nas plataformas...
#
# ðŸ”� Buscando: 'gerente comercial'
#   â†’ Indeed...
#   [Indeed] Erro ao buscar 'gerente comercial': 403 Client Error: Forbidden for url: https://br.indeed.com/jobs?q=gerente+comercial&l=Brasil&fromage=1&sort=date
#   â†’ Gupy...
#   [Gupy] Erro ao buscar 'gerente comercial': 400 Client Error: Bad Request for url: https://portal.api.gupy.io/api/job?jobName=gerente+comercial&limit=20&offset=0
#   â†’ LinkedIn...
#
# ðŸ”� Buscando: 'gerente geral'
#   â†’ Indeed...
#   [Indeed] Erro ao buscar 'gerente geral': 403 Client Error: Forbidden for url: https://br.indeed.com/jobs?q=gerente+geral&l=Brasil&fromage=1&sort=date
#   â†’ Gupy...
#   [Gupy] Erro ao buscar 'gerente geral': 400 Client Error: Bad Request for url: https://portal.api.gupy.io/api/job?jobName=gerente+geral&limit=20&offset=0
#   â†’ LinkedIn...
#
# ...

# %%
bat_content = r"""@echo off
cd /d "C:\Users\Minoru\OneDrive\Documentos\Minoru\Projetos_Python\job_hunter"
"C:\Users\Minoru\anaconda3\python.exe" job_hunter.py >> log_execucao.txt 2>&1
"""

with open(r"C:\Users\Minoru\OneDrive\Documentos\Minoru\Projetos_Python\job_hunter\rodar_job_hunter.bat", "w") as f:
    f.write(bat_content)

print("✅ Arquivo .bat criado!")
# Out:
# ✅ Arquivo .bat criado!

# %%
with open(r"C:\Users\Minoru\OneDrive\Documentos\Minoru\Projetos_Python\job_hunter\job_hunter.py", "r", encoding="utf-8") as f:
    linhas = f.readlines()

for i, linha in enumerate(linhas, 1):
    if any(x in linha.lower() for x in ["def scrape_indeed", "def scrape_gupy", "def buscar_indeed", "def buscar_gupy", "def fetch_indeed", "def fetch_gupy"]):
        print(f"Linha {i}: {linha.strip()}")

# %%
# !python "C:\Users\Minoru\OneDrive\Documentos\Minoru\Projetos_Python\job_hunter\job_hunter.py"
# Out:
# ...
#   ðŸŽ¯ JOB HUNTER â€“ Iniciando busca de vagas
#   ðŸ“… 09/04/2026 10:12
# ...
#
# ðŸ“‚ Cache carregado: 121 vagas jÃ¡ vistas
#
# ðŸŒ� Iniciando coleta nas plataformas...
#
# ðŸ”� Buscando: 'gerente comercial'
#   â†’ Indeed...
#   [Indeed] Erro ao buscar 'gerente comercial': 403 Client Error: Forbidden for url: https://br.indeed.com/jobs?q=gerente+comercial&l=Brasil&fromage=1&sort=date
#   â†’ Gupy...
#   [Gupy] Erro ao buscar 'gerente comercial': 400 Client Error: Bad Request for url: https://portal.api.gupy.io/api/job?jobName=gerente+comercial&limit=20&offset=0
#   â†’ LinkedIn...
#
# ðŸ”� Buscando: 'gerente geral'
#   â†’ Indeed...
#   [Indeed] Erro ao buscar 'gerente geral': 403 Client Error: Forbidden for url: https://br.indeed.com/jobs?q=gerente+geral&l=Brasil&fromage=1&sort=date
#   â†’ Gupy...
#   [Gupy] Erro ao buscar 'gerente geral': 400 Client Error: Bad Request for url: https://portal.api.gupy.io/api/job?jobName=gerente+geral&limit=20&offset=0
#   â†’ LinkedIn...
#
# ...

# %%
with open(r"C:\Users\Minoru\OneDrive\Documentos\Minoru\Projetos_Python\job_hunter\job_hunter.py", "r", encoding="utf-8") as f:
    linhas = f.readlines()

for i, linha in enumerate(linhas, 1):
    if any(x in linha.lower() for x in ["def scrape_indeed", "def scrape_gupy", "def buscar_indeed", "def buscar_gupy", "def fetch_indeed", "def fetch_gupy"]):
        print(f"Linha {i}: {linha.strip()}")

# %%
with open(r"C:\Users\Minoru\OneDrive\Documentos\Minoru\Projetos_Python\job_hunter\job_hunter.py", "r", encoding="utf-8") as f:
    linhas = f.readlines()

for i, linha in enumerate(linhas, 1):
    if "def " in linha:
        print(f"Linha {i}: {linha.strip()}")
# Out:
# Linha 57: def load_cache(path: str) -> set:
# Linha 64: def save_cache(path: str, seen: set):
# Linha 71: def search_indeed(keyword: str, location: str, max_results: int = 20) -> list[dict]:
# Linha 115: def search_gupy(keyword: str, max_results: int = 20) -> list[dict]:
# Linha 150: def search_linkedin(keyword: str, location: str, max_results: int = 20) -> list[dict]:
# Linha 201: def collect_all_jobs(config: dict) -> list[dict]:
# Linha 227: def filter_new_jobs(jobs: list[dict], cache: set, cache_path: str) -> list[dict]:
# Linha 250: def build_html_report(jobs: list[dict], config: dict) -> str:
# Linha 429: def send_email(html_body: str, total_jobs: int, config: dict):
# Linha 449: def main():

# %%
with open(r"C:\Users\Minoru\OneDrive\Documentos\Minoru\Projetos_Python\job_hunter\job_hunter.py", "r", encoding="utf-8") as f:
    linhas = f.readlines()

# Mostra da linha 71 até 149 (indeed + gupy)
for i, linha in enumerate(linhas[70:149], 71):
    print(f"{i}: {linha}", end="")
# Out:
# 71: def search_indeed(keyword: str, location: str, max_results: int = 20) -> list[dict]:
# 72:     """Busca vagas no Indeed Brasil"""
# 73:     jobs = []
# 74:     query = keyword.replace(" ", "+")
# 75:     loc = location.replace(" ", "+")
# 76:     url = f"https://br.indeed.com/jobs?q={query}&l={loc}&fromage=1&sort=date"
# 77:
# 78:     try:
# 79:         resp = requests.get(url, headers=HEADERS, timeout=15)
# 80:         resp.raise_for_status()
# 81:         soup = BeautifulSoup(resp.text, "html.parser")
# 82:
# 83:         cards = soup.select("div.job_seen_beacon")[:max_results]
# 84:         for card in cards:
# 85:             title_el = card.select_one("h2.jobTitle span")
# 86:             company_el = card.select_one("span[data-testid='company-name']")
# 87:             location_el = card.select_one("div[data-testid='text-location']")
# 88:             link_el = card.select_one("a[id^='job_']")
# ...

# %%
with open(r"C:\Users\Minoru\OneDrive\Documentos\Minoru\Projetos_Python\job_hunter\job_hunter.py", "r", encoding="utf-8") as f:
    conteudo = f.read()

nova_indeed = '''def search_indeed(keyword: str, location: str, max_results: int = 20) -> list[dict]:
    """Busca vagas no Indeed Brasil via RSS"""
    jobs = []
    query = keyword.replace(" ", "+")
    url = f"https://br.indeed.com/rss?q={query}&l=Brasil&sort=date&fromage=1"

    try:
        resp = requests.get(url, headers=HEADERS, timeout=15)
        resp.raise_for_status()
        soup = BeautifulSoup(resp.text, "xml")

        items = soup.find_all("item")[:max_results]
        for item in items:
            title = item.find("title").get_text(strip=True) if item.find("title") else "N/A"
            company_loc = item.find("source").get_text(strip=True) if item.find("source") else "N/A"
            link = item.find("link").get_text(strip=True) if item.find("link") else "#"
            pub_date = item.find("pubDate").get_text(strip=True) if item.find("pubDate") else "Hoje"
            guid = item.find("guid").get_text(strip=True) if item.find("guid") else link

            jobs.append({
                "id": f"indeed_{abs(hash(guid))}",
                "title": title,
                "company": company_loc,
                "location": location,
                "url": link,
                "date": pub_date,
                "source": "Indeed",
                "keyword": keyword,
            })

        time.sleep(2)
    except Exception as e:
        print(f"  [Indeed] Erro ao buscar '{keyword}': {e}")

    return jobs'''

nova_gupy = '''def search_gupy(keyword: str, max_results: int = 20) -> list[dict]:
    """Busca vagas via API pública da Gupy"""
    jobs = []
    query = keyword.replace(" ", "%20")
    url = f"https://portal.api.gupy.io/api/v1/jobs?name={query}&limit={max_results}&offset=0"

    try:
        resp = requests.get(url, headers=HEADERS, timeout=15)
        resp.raise_for_status()
        data = resp.json()

        for job in data.get("data", []):
            pub_date = job.get("publishedDate", "")[:10] if job.get("publishedDate") else ""
            jobs.append({
                "id": f"gupy_{job.get('id', '')}",
                "title": job.get("name", "N/A"),
                "company": job.get("careerPageName", "N/A"),
                "location": f"{job.get('city', '')} - {job.get('state', '')}".strip(" -"),
                "url": job.get("jobUrl", "#"),
                "date": pub_date,
                "source": "Gupy",
                "keyword": keyword,
            })

        time.sleep(1)
    except Exception as e:
        print(f"  [Gupy] Erro ao buscar '{keyword}': {e}")

    return jobs'''

# Substitui as funções antigas
import re
conteudo = re.sub(
    r"def search_indeed\(.*?return jobs\n",
    nova_indeed + "\n",
    conteudo,
    flags=re.DOTALL
)
conteudo = re.sub(
    r"def search_gupy\(.*?return jobs\n",
    nova_gupy + "\n",
    conteudo,
    flags=re.DOTALL
)

with open(r"C:\Users\Minoru\OneDrive\Documentos\Minoru\Projetos_Python\job_hunter\job_hunter.py", "w", encoding="utf-8") as f:
    f.write(conteudo)

print("✅ Funções Indeed e Gupy atualizadas!")
# Out:
# ✅ Funções Indeed e Gupy atualizadas!

# %%
# !python "C:\Users\Minoru\OneDrive\Documentos\Minoru\Projetos_Python\job_hunter\job_hunter.py"
# Out:
# ...
#   ðŸŽ¯ JOB HUNTER â€“ Iniciando busca de vagas
#   ðŸ“… 09/04/2026 10:16
# ...
#
# ðŸ“‚ Cache carregado: 123 vagas jÃ¡ vistas
#
# ðŸŒ� Iniciando coleta nas plataformas...
#
# ðŸ”� Buscando: 'gerente comercial'
#   â†’ Indeed...
#   [Indeed] Erro ao buscar 'gerente comercial': 403 Client Error: Forbidden for url: https://br.indeed.com/rss?q=gerente+comercial&l=Brasil&sort=date&fromage=1
#   â†’ Gupy...
#   [Gupy] Erro ao buscar 'gerente comercial': 400 Client Error: Bad Request for url: https://portal.api.gupy.io/api/v1/jobs?name=gerente%20comercial&limit=20&offset=0
#   â†’ LinkedIn...
#
# ðŸ”� Buscando: 'gerente geral'
#   â†’ Indeed...
#   [Indeed] Erro ao buscar 'gerente geral': 403 Client Error: Forbidden for url: https://br.indeed.com/rss?q=gerente+geral&l=Brasil&sort=date&fromage=1
#   â†’ Gupy...
#   [Gupy] Erro ao buscar 'gerente geral': 400 Client Error: Bad Request for url: https://portal.api.gupy.io/api/v1/jobs?name=gerente%20geral&limit=20&offset=0
#   â†’ LinkedIn...
#
# ...

# %%
with open(r"C:\Users\Minoru\OneDrive\Documentos\Minoru\Projetos_Python\job_hunter\job_hunter.py", "r", encoding="utf-8") as f:
    linhas = f.readlines()

for i, linha in enumerate(linhas[149:200], 150):
    print(f"{i}: {linha}", end="")
# Out:
# 150:     try:
# 151:         resp = requests.get(url, headers=HEADERS, timeout=15)
# 152:         resp.raise_for_status()
# 153:         soup = BeautifulSoup(resp.text, "html.parser")
# 154:
# 155:         cards = soup.select("div.base-card")[:max_results]
# 156:         for card in cards:
# 157:             title_el = card.select_one("h3.base-search-card__title")
# 158:             company_el = card.select_one("h4.base-search-card__subtitle")
# 159:             location_el = card.select_one("span.job-search-card__location")
# 160:             link_el = card.select_one("a.base-card__full-link")
# 161:             date_el = card.select_one("time")
# 162:
# 163:             if not title_el or not link_el:
# 164:                 continue
# 165:
# 166:             href = link_el.get("href", "#")
# 167:             job_id = re.search(r"-(\d+)\??", href)
# 168:             job_id = job_id.group(1) if job_id else href[-10:]
# 169:
# 170:             jobs.append({
# ...

# %%
with open(r"C:\Users\Minoru\OneDrive\Documentos\Minoru\Projetos_Python\job_hunter\job_hunter.py", "r", encoding="utf-8") as f:
    linhas = f.readlines()

for i, linha in enumerate(linhas[149:155], 150):
    print(f"{i}: {linha}", end="")
# Out:
# 150:     try:
# 151:         resp = requests.get(url, headers=HEADERS, timeout=15)
# 152:         resp.raise_for_status()
# 153:         soup = BeautifulSoup(resp.text, "html.parser")
# 154:
# 155:         cards = soup.select("div.base-card")[:max_results]

# %%
with open(r"C:\Users\Minoru\OneDrive\Documentos\Minoru\Projetos_Python\job_hunter\job_hunter.py", "r", encoding="utf-8") as f:
    linhas = f.readlines()

for i, linha in enumerate(linhas[139:152], 140):
    print(f"{i}: {linha}", end="")
# Out:
# 140:     """Busca vagas no LinkedIn (scraping público, sem login)"""
# 141:     jobs = []
# 142:     query = keyword.replace(" ", "%20")
# 143:     loc = location.replace(" ", "%20")
# 144:     # LinkedIn permite busca pública sem login nesta URL
# 145:     url = (
# 146:         f"https://www.linkedin.com/jobs/search/"
# 147:         f"?keywords={query}&location={loc}&f_TPR=r86400&sortBy=DD"
# 148:     )
# 149:
# 150:     try:
# 151:         resp = requests.get(url, headers=HEADERS, timeout=15)
# 152:         resp.raise_for_status()

# %%
with open(r"C:\Users\Minoru\OneDrive\Documentos\Minoru\Projetos_Python\job_hunter\job_hunter.py", "r", encoding="utf-8") as f:
    linhas = f.readlines()

for i, linha in enumerate(linhas, 1):
    if "location" in linha.lower() and i < 60:
        print(f"{i}: {linha}", end="")
# Out:
# 25:     "location": "Brasil",

# %%
with open(r"C:\Users\Minoru\OneDrive\Documentos\Minoru\Projetos_Python\job_hunter\job_hunter.py", "r", encoding="utf-8") as f:
    conteudo = f.read()

conteudo = conteudo.replace(
    'f"https://www.linkedin.com/jobs/search/"\n        f"?keywords={query}&location={loc}&f_TPR=r86400&sortBy=DD"',
    'f"https://www.linkedin.com/jobs/search/?keywords={query}&location={loc}&geoId=106057199&f_TPR=r86400&sortBy=DD"'
)

with open(r"C:\Users\Minoru\OneDrive\Documentos\Minoru\Projetos_Python\job_hunter\job_hunter.py", "w", encoding="utf-8") as f:
    f.write(conteudo)

print("✅ LinkedIn atualizado para filtrar apenas Brasil!")
# Out:
# ✅ LinkedIn atualizado para filtrar apenas Brasil!

# %%
# !python "C:\Users\Minoru\OneDrive\Documentos\Minoru\Projetos_Python\job_hunter\job_hunter.py"
# Out:
# ...
#   ðŸŽ¯ JOB HUNTER â€“ Iniciando busca de vagas
#   ðŸ“… 27/05/2026 13:36
# ...
#
# ðŸ“‚ Cache carregado: 1296 vagas jÃ¡ vistas
#
# ðŸŒ� Iniciando coleta nas plataformas...
#
# ðŸ”� Buscando: 'gerente comercial'
#   â†’ LinkedIn...
#
# ðŸ”� Buscando: 'gerente geral'
#   â†’ LinkedIn...
#
# ðŸ”� Buscando: 'diretor comercial'
#   â†’ LinkedIn...
#
# ðŸ”� Buscando: 'Cientista de Dados'
#   â†’ LinkedIn...
#
# ðŸ”� Buscando: 'Analista de Dados'
#   â†’ LinkedIn...
#
# ðŸ“Š Total coletado (com duplicatas): 81
# âœ¨ Vagas novas (nÃ£o vistas antes): 80
# ðŸ’¾ RelatÃ³rio salvo localmente: report_20260527.html
#
# ðŸ“§ Enviando email para cmabe01@gmail.com...
#   âœ… Email enviado com sucesso!
#
# âœ… Job Hunter finalizado!
